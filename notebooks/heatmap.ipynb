# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

# %%
def plot_heatmap(df, title, size, savefile=None):
    # Plot it out
    fig, ax = plt.subplots()
    heatmap = ax.pcolor(df, cmap=plt.cm.Blues, alpha=0.8, vmin=0., vmax=1.)

    # Format
    fig = plt.gcf()
    fig.set_size_inches(size[0], size[1])

    # turn off the frame
    ax.set_frame_on(False)

    # put the major ticks at the middle of each cell
    ax.set_yticks(np.arange(df.shape[0])+0.5, minor=False)
    ax.set_xticks(np.arange(df.shape[1])+0.5, minor=False)

    # set values for x and y axis ticks
    ax.set_xticklabels(df.columns, minor=False, fontsize=15) 
    ax.set_yticklabels(df.index, minor=False, fontsize=15)

    # turn off grid mode
    ax.grid(False)
    
    # set plot title and axis labels
    ax.set_title(title, fontsize=20, y = 1.03)
    ax.set_xlabel('# Categories', fontsize=20)
    ax.set_ylabel('# Exemplars', fontsize=20)
    
    cbar = plt.colorbar(heatmap)
    cbar.set_label('Accuracy', rotation=270, fontsize=20, labelpad=25)
    if savefile is not None:
        plt.savefig(
            savefile, 
            format='pdf',
            bbox_inches='tight'
        )
    else:
        plt.show()

# %%
df_first1 = pd.read_csv('../results/mlp_results_firstOrder1.csv', index_col=0)
df_first2 = pd.read_csv('../results/mlp_results_firstOrder2.csv', index_col=0)
df_second1 = pd.read_csv('../results/mlp_results_secondOrder1.csv', index_col=0)
df_second2 = pd.read_csv('../results/mlp_results_secondOrder2.csv', index_col=0)

# %%
df_first1
# Out:
#        5    10        15    20     25        30        35     40        45  \
# 1   0.44  0.64  0.506667  0.51  0.272  0.320000  0.360000  0.260  0.275556
# 2   0.56  0.56  0.560000  0.52  0.648  0.586667  0.651429  0.690  0.604444
# 3   0.68  0.78  0.893333  0.86  0.872  0.906667  0.862857  0.815  0.848889
# 4   1.00  1.00  0.986667  0.96  0.968  0.953333  0.971429  0.970  0.982222
# 5   1.00  1.00  0.960000  1.00  0.992  1.000000  1.000000  1.000  1.000000
# 6   1.00  0.94  0.960000  1.00  0.968  1.000000  1.000000  1.000  1.000000
# 7   1.00  1.00  1.000000  1.00  1.000  1.000000  1.000000  1.000  1.000000
# 8   1.00  1.00  1.000000  1.00  1.000  1.000000  1.000000  1.000  1.000000
# 9   1.00  1.00  1.000000  1.00  1.000  1.000000  1.000000  1.000  1.000000
# 10  1.00  1.00  1.000000  1.00  1.000  1.000000  1.000000  1.000  1.000000
# 11  1.00  1.00  1.000000  1.00  1.000  1.000000  1.000000  1.000  1.000000
# 12  1.00  1.00  1.000000  1.00  1.000  1.000000  1.000000  1.000  1.000000
# 13  1.00  1.00  1.000000  1.00  1.000  1.000000  1.000000  1.000  1.000000
# 14  1.00  1.00  1.000000  1.00  1.000  1.000000  1.000000  1.000  1.000000
#
#        50
# 1   0.208
# 2   0.692
# 3   0.916
# 4   0.968
# 5   1.000
# 6   1.000
# 7   0.984
# 8   1.000
# 9   1.000
# 10  1.000
# 11  1.000
# 12  1.000
# 13  1.000
# 14  1.000

# %%
plot_heatmap(
    df_first1.loc[1:12],
    title='First-order Generalization',
    size=(8, 9),
    savefile='/Users/reubenfeinman/Desktop/ffn_1order_accuracy.pdf'
)

# %%
plot_heatmap(df_first2, 
             title='First-order Generalization Results',
             size=(4,6))

# %%
plot_heatmap(
    df_second1.loc[1:12], 
    'Second-order Generalization',
    size=(8,9),
    savefile='/Users/reubenfeinman/Desktop/ffn_2order_accuracy.pdf'
)

# %%
plot_heatmap(df_second2, 
             'Second-order Generalization Results',
             size=(4,6))

# %%
df_first_noise = pd.read_csv('../results/results_firstOrder_noise10p.csv', index_col=0)
df_second_noise = pd.read_csv('../results/results_secondOrder_noise10p.csv', index_col=0)

# %%
plot_heatmap(df_first_noise, 
             title='First-order Generalization Results w/ p=0.1 noise (classification accuracy)',
             size=(8, 11))

# %%
df_second_noise.fillna(value=0)
# Out:
#        5    10        15    20     25        30        35     40        45
# 1   0.28  0.44  0.266667  0.31  0.392  0.300000  0.440000  0.380  0.417778
# 2   0.32  0.44  0.293333  0.48  0.528  0.446667  0.525714  0.530  0.511111
# 3   0.48  0.50  0.560000  0.65  0.680  0.646667  0.702857  0.810  0.711111
# 4   0.72  0.58  0.693333  0.69  0.816  0.806667  0.754286  0.845  0.862222
# 5   0.28  0.68  0.626667  0.70  0.784  0.846667  0.885714  0.955  0.968889
# 6   0.52  0.62  0.920000  0.81  0.888  0.953333  0.965714  0.945  0.986667
# 7   0.64  0.72  0.880000  0.93  0.920  0.946667  0.977143  0.955  1.000000
# 8   0.48  0.68  0.800000  0.99  0.976  1.000000  0.982857  1.000  0.000000
# 9   0.80  0.68  0.973333  0.91  0.928  1.000000  0.971429  0.995  0.000000
# 10  0.68  0.80  0.986667  0.95  1.000  0.986667  0.988571  0.995  0.000000
# 11  0.60  0.86  0.960000  0.98  0.992  0.986667  1.000000  1.000  0.000000
# 12  0.80  0.92  0.960000  0.94  1.000  1.000000  0.994286  1.000  0.000000
# 13  0.64  0.88  0.906667  1.00  1.000  1.000000  1.000000  1.000  0.000000
# 14  0.96  0.86  0.933333  0.99  0.976  1.000000  1.000000  1.000  0.000000

# %%
plot_heatmap(df_second_noise.fillna(value=0), 
             'Second-order Generalization Results w/ p=0.1 noise (% correct)',
             size=(8,11))

# %%
df_second1.loc[1:12]
# Out:
#        5    10        15    20     25        30        35     40        45  \
# 1   0.20  0.42  0.240000  0.26  0.216  0.340000  0.337143  0.315  0.306667
# 2   0.36  0.40  0.560000  0.38  0.576  0.453333  0.645714  0.560  0.648889
# 3   0.60  0.58  0.733333  0.65  0.704  0.760000  0.822857  0.865  0.880000
# 4   0.56  0.68  0.800000  0.78  0.880  0.866667  0.891429  0.990  0.977778
# 5   0.32  0.62  0.893333  0.94  0.984  0.966667  0.971429  0.975  0.986667
# 6   0.32  0.82  0.920000  0.98  0.968  1.000000  1.000000  0.990  0.995556
# 7   0.64  0.82  0.906667  0.99  0.976  0.993333  0.988571  1.000  1.000000
# 8   0.92  0.90  0.973333  0.99  0.952  1.000000  1.000000  1.000  1.000000
# 9   0.84  0.94  1.000000  1.00  1.000  1.000000  1.000000  1.000  1.000000
# 10  0.92  0.88  1.000000  0.97  1.000  1.000000  1.000000  1.000  1.000000
# 11  0.92  1.00  1.000000  1.00  1.000  1.000000  1.000000  1.000  1.000000
# 12  0.96  1.00  0.986667  1.00  1.000  1.000000  1.000000  1.000  1.000000
#
#        50
# 1   0.308
# 2   0.672
# 3   0.968
# 4   0.984
# 5   0.984
# 6   1.000
# 7   1.000
# 8   1.000
# 9   1.000
# 10  1.000
# 11  1.000
# 12  1.000

# %% [markdown]
# # Image CNN results

# %% [markdown]
# ## With color subsampling function (log scale)

# %%
df_first_img = pd.read_csv('../results/cnn_results_firstOrder/results.csv', index_col=0)
plot_heatmap(
    df_first_img.loc[1:12], 
    'First-order Generalization',
    size=(8,9),
    #savefile='/Users/reubenfeinman/Desktop/cnn_1order_accuracy.pdf'
)

# %%
df_first_img = pd.read_csv('../results/cnn_results_firstOrder_log/results.csv', index_col=0)
plot_heatmap(
    df_first_img.loc[1:12], 
    'First-order Generalization',
    size=(8,9),
    #savefile='/Users/reubenfeinman/Desktop/cnn_1order_accuracy.pdf'
)

# %%
df_second_img = pd.read_csv('../results/cnn_results_secondOrder/results.csv', index_col=0)
plot_heatmap(
    df_second_img.loc[1:12],
    'Second-order Generalization',
    size=(8,9),
    #savefile='/Users/reubenfeinman/Desktop/cnn_2order_accuracy.pdf'
)

# %%
df_second_img = pd.read_csv('../results/cnn_results_secondOrder_log/results.csv', index_col=0)
plot_heatmap(
    df_second_img.loc[1:12],
    'Second-order Generalization',
    size=(8,9),
    #savefile='/Users/reubenfeinman/Desktop/cnn_2order_accuracy.pdf'
)

# %% [markdown]
# ## Without color subsampling function

# %%
df_first_img = pd.read_csv('../results/cnn_results_firstOrder_colorOld/results.csv', index_col=0)
plot_heatmap(
    df_first_img.loc[1:12], 
    'First-order Generalization',
    size=(8,9),
    #savefile='/Users/reubenfeinman/Desktop/cnn_1order_accuracy.pdf'
)

# %% [markdown]
# ## These are results from old data (MPL images) when I first got rid of dataset noise

# %%
df_first_img = pd.read_csv('../results/cnn_results_firstOrder1/results.csv', index_col=0)
plot_heatmap(
    df_first_img.loc[1:12], 
    'First-order Generalization',
    size=(8,9),
    savefile='/Users/reubenfeinman/Desktop/cnn_1order_accuracy.pdf'
)

# %%
df_second_img = pd.read_csv('../results/cnn_results_secondOrder1/results.csv', index_col=0)
plot_heatmap(
    df_second_img.loc[1:12],
    'Second-order Generalization',
    size=(8,9),
    savefile='/Users/reubenfeinman/Desktop/cnn_2order_accuracy.pdf'
)
