# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

# %%
df_first1 = pd.read_csv('../results/results_firstOrder1.csv', index_col=0)
df_first2 = pd.read_csv('../results/results_firstOrder2.csv', index_col=0)
df_second1 = pd.read_csv('../results/results_secondOrder1.csv', index_col=0)
df_second2 = pd.read_csv('../results/results_secondOrder2.csv', index_col=0)

# %%
df_first1
# Out:
#       5   10        15    20    25        30        35     40        45    50
# 1   0.6  0.5  0.266667  0.35  0.28  0.233333  0.057143  0.100  0.155556  0.22
# 2   0.8  0.9  0.466667  0.45  0.44  0.433333  0.457143  0.650  0.333333  0.42
# 3   0.8  0.5  0.666667  0.65  0.52  0.600000  0.800000  0.675  0.711111  0.74
# 4   0.6  0.7  0.600000  0.80  0.92  0.833333  0.742857  0.900  0.800000  0.98
# 5   0.6  0.9  0.933333  0.90  0.88  0.933333  0.971429  1.000  0.933333  1.00
# 6   1.0  1.0  0.933333  1.00  1.00  1.000000  1.000000  1.000  1.000000  0.98
# 7   1.0  1.0  1.000000  1.00  1.00  1.000000  1.000000  1.000  1.000000  1.00
# 8   1.0  1.0  1.000000  0.95  1.00  1.000000  1.000000  1.000  1.000000  1.00
# 9   1.0  1.0  1.000000  1.00  1.00  1.000000  1.000000  1.000  1.000000  1.00
# 10  1.0  1.0  1.000000  1.00  1.00  1.000000  1.000000  1.000  1.000000  1.00
# 11  1.0  1.0  1.000000  1.00  1.00  1.000000  1.000000  1.000  1.000000  1.00
# 12  1.0  1.0  1.000000  1.00  1.00  1.000000  1.000000  1.000  1.000000  1.00
# 13  1.0  1.0  1.000000  1.00  1.00  1.000000  1.000000  1.000  1.000000  1.00
# 14  1.0  1.0  1.000000  1.00  1.00  1.000000  1.000000  1.000  1.000000  1.00

# %%
def plot_heatmap(df, title, size):
    # Plot it out
    fig, ax = plt.subplots()
    heatmap = ax.pcolor(df, cmap=plt.cm.Blues, alpha=0.8)

    # Format
    fig = plt.gcf()
    fig.set_size_inches(size[0], size[1])

    # turn off the frame
    ax.set_frame_on(False)

    # put the major ticks at the middle of each cell
    ax.set_yticks(np.arange(df.shape[0])+0.5, minor=False)
    ax.set_xticks(np.arange(df.shape[1])+0.5, minor=False)

    # set values for x and y axis ticks
    ax.set_xticklabels(df.columns, minor=False, fontsize=15) 
    ax.set_yticklabels(df.index, minor=False, fontsize=15)

    # turn off grid mode
    ax.grid(False)
    
    # set plot title and axis labels
    ax.set_title(title, fontsize=20, y = 1.03)
    ax.set_xlabel('# Categories', fontsize=20)
    ax.set_ylabel('# Exemplars', fontsize=20)
    
    plt.colorbar(heatmap)

# %%
plot_heatmap(df_first1, 
             title='First-order Generalization Results (classification accuracy)',
             size=(8, 11))

# %%
plot_heatmap(df_first2, 
             title='First-order Generalization Results (classification accuracy)',
             size=(4,6))

# %%
plot_heatmap(df_second1, 
             'Second-order Generalization Results (% of time similarity score correct)',
             size=(8,11))

# %%
plot_heatmap(df_second2, 
             'Second-order Generalization Results (% of time similarity score correct)',
             size=(4,6))
